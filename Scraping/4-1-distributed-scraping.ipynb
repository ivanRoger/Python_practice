# %% [markdown]
# ## Distributed scraping: multiprocessing
# Speed up scraping by distributed crawling and parsing. I'm going to scrape my website but in a local server "http://127.0.0.1:4000/" to eliminate different downloading speed. This test is more accurate in time measuring. You can use "https://morvanzhou.github.io/" instead, because you cannot access "http://127.0.0.1:4000/".
#
# #### We gonna scrape all web pages in my website and reture the title and url for each page.

# %%
import multiprocessing as mp
import time
from urllib.request import urlopen, urljoin
from bs4 import BeautifulSoup
import re

base_url = "https://morvanzhou.github.io/"
# base_url = "http://127.0.0.1:4000/" 為莫凡內網，爬不了，所以要用外網爬

# DON'T OVER CRAWL THE WEBSITE OR YOU MAY NEVER VISIT AGAIN
if base_url != "https://morvanzhou.github.io/":
    restricted_crawl = True
else:
    restricted_crawl = False

# %% [markdown]
# #### Create a crawl function to open a url in parallel.

# %%
def crawl(url):
    response = urlopen(url)
    time.sleep(0.1)             # slightly delay for downloading
    return response.read().decode()

# %% [markdown]
# #### Create a parse function to find all results we need in parallel

# %%
def parse(html):
    soup = BeautifulSoup(html, features='html.parser')
    urls = soup.find_all('a', {"href": re.compile('^/.+?/$')})
    title = soup.find('h1').get_text().strip()
    page_urls = set([urljoin(base_url, url['href']) for url in urls])
    url = soup.find('meta', {'property': "og:url"})['content']
    return title, page_urls, url

# %% [markdown]
# ### Normal way
# Do not use multiprocessing, test the speed. Firstly, set what urls we have already seen and what we haven't in a python set.

# %%
unseen = set([base_url,])
seen = set()

count, t1 = 1, time.time()

while len(unseen) != 0:                 # still get some url to visit
    if restricted_crawl and len(seen) > 20:
            break
        
    print('\nDistributed Crawling...')
    htmls = [crawl(url) for url in unseen]

    print('\nDistributed Parsing...')
    results = [parse(html) for html in htmls]

    print('\nAnalysing...')
    seen.update(unseen)         # seen the crawled
    unseen.clear()              # nothing unseen

    for title, page_urls, url in results:
        print(count, title, url)
        count += 1
        unseen.update(page_urls - seen)     # get new url to crawl
print('Total time: %.1f s' % (time.time()-t1, ))    # 53 s
# Out:
# Distributed Crawling...
#
# Distributed Parsing...
#
# Analysing...
# 1 教程 https://morvanzhou.github.io/
#
# Distributed Crawling...
#
# Distributed Parsing...
#
# Analysing...
# 2 其他教学系列 https://morvanzhou.github.io/tutorials/others/
# 3 Git 版本管理 教程系列 https://morvanzhou.github.io/tutorials/others/git/
# 4 说吧~ https://morvanzhou.github.io/discuss/
# 5 Tensorflow 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/
# 6 Pytorch 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/torch/
# 7 Tkinter GUI 教程系列 https://morvanzhou.github.io/tutorials/python-basic/tkinter/
# 8 Matplotlib 画图教程系列 https://morvanzhou.github.io/tutorials/data-manipulation/plt/
# 9 推荐学习顺序 https://morvanzhou.github.io/learning-steps/
# 10 高级爬虫: 让 Selenium 控制你的浏览器帮你爬 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/5-01-selenium/
# 11 计算机视觉 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/computer-vision/
# 12 为了更优秀 https://morvanzhou.github.io/support/
# 13 网页爬虫教程系列 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/
# 14 迁移学习 Transfer Learning https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-16-transfer-learning/
# 15 Linux 简易教学 https://morvanzhou.github.io/tutorials/others/linux-basic/
# 16 Why? https://morvanzhou.github.io/tutorials/data-manipulation/scraping/1-00-why/
# 17 高级爬虫: 高效无忧的 Scrapy 爬虫库 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/5-02-scrapy/
# 18 multiprocessing 多进程教程系列 https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/
# 19 基础教程系列 https://morvanzhou.github.io/tutorials/python-basic/basic/
# 20 迁移学习 Transfer Learning https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-9-transfer-learning/
# 21 Threading 多线程教程系列 https://morvanzhou.github.io/tutorials/python-basic/threading/
# 22 Theano 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/theano/
# 23 近期更新 https://morvanzhou.github.io/recent-posts/
# 24 机器学习系列 https://morvanzhou.github.io/tutorials/machine-learning/
# 25 Keras 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/keras/
# 26 Sklearn 通用机器学习 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/
# 27 数据处理教程系列 https://morvanzhou.github.io/tutorials/data-manipulation/
# 28 进化算法 Evolutionary Strategies 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/
# 29 Python基础 教程系列 https://morvanzhou.github.io/tutorials/python-basic/
# 30 强化学习 Reinforcement Learning 教程系列 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/
# 31 机器学习实践 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/
# 32 Numpy & Pandas 教程系列 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/
# 33 有趣的机器学习系列 https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/
# 34 关于莫烦 https://morvanzhou.github.io/about/
#
# Distributed Crawling...
#
# Distributed Parsing...
#
# Analysing...
# 35 自己的云计算, 多电脑共享你云端文件 https://morvanzhou.github.io/tutorials/others/linux-basic/5-02-share-folder/
# 36 Dropout 解决 overfitting https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-02-dropout/
# 37 例子 登录窗口1 https://morvanzhou.github.io/tutorials/python-basic/tkinter/3-01-example1/
# 38 Why Pytorch? https://morvanzhou.github.io/tutorials/machine-learning/torch/1-1-why/
# 39 RNN 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-07-RNN1/
# 40 什么是过拟合 (Overfitting) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-02-A-overfitting/
# 41 激励函数 Activation Function https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-6-activation/
# 42 RNN LSTM 循环神经网络 (分类例子) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-08-RNN2/
# 43 Double DQN (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-5-double_DQN/
# 44 Shared 变量 https://morvanzhou.github.io/tutorials/machine-learning/theano/2-3-shared-variable/
# 45 BeautifulSoup 解析网页: 正则表达 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/2-03-beautifulsoup-regex/
# 46 print 功能 https://morvanzhou.github.io/tutorials/python-basic/basic/02-1-print/
# 47 Linux 文件权限 https://morvanzhou.github.io/tutorials/others/linux-basic/3-01-file-permissions/
# 48 list 列表 https://morvanzhou.github.io/tutorials/python-basic/basic/11-2-list/
# 49 Tensorboard 可视化好帮手 1 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/4-1-tensorboard1/
# 50 科普: 人工神经网络 VS 生物神经网络 https://morvanzhou.github.io/tutorials/machine-learning/theano/1-1-A-ANN-and-NN/
# 51 什么是 Policy Gradients https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/5-1-A-PG/
# 52 Evolution Strategy 强化学习 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/4-04-evolution-strategy-reinforcement-learning/
# 53 Scale 尺度 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-05-scale/
# 54 定义 Layer 类 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-1-layer/
# 55 科普: 人工神经网络 VS 生物神经网络 https://morvanzhou.github.io/tutorials/machine-learning/torch/1-1-A-ANN-and-NN/
# 56 Policy Gradients 算法更新 (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/5-1-policy-gradient-softmax1/
# 57 pickle 保存数据 https://morvanzhou.github.io/tutorials/python-basic/basic/13-08-pickle/
# 58 DQN 思维决策 (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-3-DQN3/
# 59 Entry & Text 输入, 文本框 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-02-entry-text/
# 60 NEAT 强化学习 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/4-03-neat-reinforcement-learning/
# 61 什么是过拟合 (Overfitting) https://morvanzhou.github.io/tutorials/machine-learning/torch/5-03-A-overfitting/
# 62 遗传算法 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/2-01-genetic-algorithm/
# 63 为什么要计算机视觉 https://morvanzhou.github.io/tutorials/machine-learning/computer-vision/1-1-why/
# 64 保存提取 https://morvanzhou.github.io/tutorials/machine-learning/torch/3-04-save-reload/
# 65 Numpy copy & deep copy https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-8-np-copy/
# 66 优化器 optimizer https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/3-4-optimizer/
# 67 Checkbutton 勾选项 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-06-checkbutton/
# 68 回到从前 (reset) https://morvanzhou.github.io/tutorials/others/git/3-1-reset/
# 69 Scatter 散点图 https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-1-scatter/
# 70 正规化 Normalization https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-1-normalization/
# 71 兼容 backend https://morvanzhou.github.io/tutorials/machine-learning/keras/1-3-backend/
# 72 什么是 Tkinter https://morvanzhou.github.io/tutorials/python-basic/tkinter/1-1-why/
# 73 Linux 基本指令 mkdir, rmdir 和 rm https://morvanzhou.github.io/tutorials/others/linux-basic/2-03-basic-command/
# 74 强化学习方法汇总 (Reinforcement Learning) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-02-RL-methods/
# 75 Why Sklearn? https://morvanzhou.github.io/tutorials/machine-learning/sklearn/1-1-why/
# 76 什么是 DQN https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-1-A-DQN/
# 77 什么是 tkinter 窗口 https://morvanzhou.github.io/tutorials/python-basic/basic/13-07-tkinter/
# 78 交叉验证 1 Cross-validation https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-2-cross-validation1/
# 79 科普: 神经网络的黑盒不黑 https://morvanzhou.github.io/tutorials/machine-learning/torch/1-1-D-feature-representation/
# 80 pack grid place 放置位置 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-11-pack-grid-place/
# 81 怎么样从 MacOS 或 Linux 通过 SSH 远程 Linux https://morvanzhou.github.io/tutorials/others/linux-basic/4-01-ssh-from-linux-or-mac/
# 82 激励函数 (Activation) https://morvanzhou.github.io/tutorials/machine-learning/torch/2-03-activation/
# 83 Subplot 分格显示 https://morvanzhou.github.io/tutorials/data-manipulation/plt/4-2-subplot2/
# 84 continue & break https://morvanzhou.github.io/tutorials/python-basic/basic/13-01-continue-break/
# 85 Natural Evolution Strategy https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/3-03-evolution-strategy-natural-evolution-strategy/
# 86 进化策略 (Evolution Strategy) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/5-02-evolution-strategy/
# 87 关系拟合 (回归) https://morvanzhou.github.io/tutorials/machine-learning/torch/3-01-regression/
# 88 scope 命名方法 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-12-scope/
# 89 为什么选 Tensorflow? https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-1-why/
# 90 Microbial Genetic Algorithm https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/2-04-microbial-genetic-algorithm/
# 91 临时修改 (stash) https://morvanzhou.github.io/tutorials/others/git/4-4-stash/
# 92 什么是自编码 (Autoencoder) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-11-A-autoencoder/
# 93 什么是 Q Leaning https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/2-1-A-q-learning/
# 94 神经网络 (Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-1-NN/
# 95 Numpy array 合并 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-6-np-concat/
# 96 记录修改 (log & diff) https://morvanzhou.github.io/tutorials/others/git/2-2-modified/
# 97 messagebox 弹窗 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-10-messagebox/
# 98 自编码 (Autoencoder) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-5-autoencoder/
# 99 Regularization 正规化 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-5-regularization/
# 100 遗传算法 (Genetic Algorithm) https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/2-00-genetic-algorithm/
# 101 快速搭建法 https://morvanzhou.github.io/tutorials/machine-learning/torch/3-03-fast-nn/
# 102 if elif else 判断 https://morvanzhou.github.io/tutorials/python-basic/basic/04-3-if-elif-else/
# 103 元组 列表 https://morvanzhou.github.io/tutorials/python-basic/basic/11-1-array-list/
# 104 set 找不同 https://morvanzhou.github.io/tutorials/python-basic/basic/13-09-set/
# 105 模块安装 https://morvanzhou.github.io/tutorials/python-basic/basic/07-1-module-install/
# 106 Optimizer 优化器 https://morvanzhou.github.io/tutorials/machine-learning/torch/3-06-optimizer/
# 107 自己的模块 https://morvanzhou.github.io/tutorials/python-basic/basic/12-2-personal-module/
# 108 Numpy array 分割 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-7-np-split/
# 109 为什么 Torch 是动态的 https://morvanzhou.github.io/tutorials/machine-learning/torch/5-01-dynamic/
# 110 神经进化 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/4-01-neuro-evolution/
# 111 Q-learning 算法更新 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/2-2-tabular-q1/
# 112 进化算法 简介 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/1-01-intro/
# 113 Save 保存 提取 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-6-save/
# 114 安装 https://morvanzhou.github.io/tutorials/python-basic/basic/01-1-install/
# 115 什么是神经网络进化 (Neuro-Evolution) https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/4-00-neuro-evolution/
# 116 NEAT 监督学习 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/4-02-neat-supervised-learning/
# 117 rebase 分支冲突 https://morvanzhou.github.io/tutorials/others/git/4-3-rebase/
# 118 Menubar 菜单 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-08-menubar/
# 119 什么是神经网络 (Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/theano/1-1-B-NN/
# 120 什么是迁移学习 Transfer Learning https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-16-A-tranfer-learning/
# 121 例子3 建造神经网络 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/3-2-create-NN/
# 122 Keras 安装 https://morvanzhou.github.io/tutorials/machine-learning/keras/1-2-install/
# 123 Deep Deterministic Policy Gradient (DDPG) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-09-DDPG/
# 124 AutoEncoder (自编码/非监督学习) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-04-autoencoder/
# 125 Github 在线代码管理 https://morvanzhou.github.io/tutorials/others/git/5-1-github/
# 126 读写文件 2 https://morvanzhou.github.io/tutorials/python-basic/basic/08-2-read-file2/
# 127 CNN 卷积神经网络 1 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-03-CNN1/
# 128 Tensorflow 2017 更新 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-14-tf2017/
# 129 DQN https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-06-DQN/
# 130 从头开始做一个机器手臂2 写静态环境 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/RL-build-arm-from-scratch2/
# 131 交叉验证 3 Cross-validation https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-4-cross-validation3/
# 132 DQN 强化学习 https://morvanzhou.github.io/tutorials/machine-learning/torch/4-05-DQN/
# 133 Batch Normalization 批标准化 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-13-BN/
# 134 神经网络进化 (Neuro-Evolution) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/5-03-neuro-evolution/
# 135 科普: 神经网络的黑盒不黑 https://morvanzhou.github.io/tutorials/machine-learning/keras/1-1-D-feature-representation/
# 136 给你的 Ubuntu 安装软件 https://morvanzhou.github.io/tutorials/others/linux-basic/1-4-install-software/
# 137 批标准化 (Batch Normalization) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-08-batch-normalization/
# 138 def 函数 https://morvanzhou.github.io/tutorials/python-basic/basic/05-1-def/
# 139 Sarsa 算法更新 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/3-1-tabular-sarsa1/
# 140 为什么用 Matplotlib https://morvanzhou.github.io/tutorials/data-manipulation/plt/1-1-why/
# 141 科普: 神经网络的黑盒不黑 https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-7-feature-representation/
# 142 什么是激励函数 (Activation Function) https://morvanzhou.github.io/tutorials/machine-learning/theano/2-4-A-activation-function/
# 143 RNN 循环神经网络 (分类) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-02-RNN-classification/
# 144 Bar 柱状图 https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-2-Bar/
# 145 Activation function 激励函数 https://morvanzhou.github.io/tutorials/machine-learning/theano/2-4-activation/
# 146 检验神经网络 (Evaluation) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-01-Evaluate-NN/
# 147 什么是 Actor Critic https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-1-A-AC/
# 148 怎么样从手机 (Android安卓/IOS苹果) 通过 SSH 远程 Linux https://morvanzhou.github.io/tutorials/others/linux-basic/4-03-ssh-from-phone/
# 149 例子 登录窗口2 https://morvanzhou.github.io/tutorials/python-basic/tkinter/3-02-example2/
# 150 处理不均衡数据 (Imbalanced data) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-07-imbalanced-data/
# 151 读写文件 1 https://morvanzhou.github.io/tutorials/python-basic/basic/08-1-read-file/
# 152 input 输入 https://morvanzhou.github.io/tutorials/python-basic/basic/10-1-input/
# 153 Policy Gradients https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-07-PG/
# 154 Legend 图例 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-5-lagend/
# 155 为什么用强化学习 Why? https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/1-1-why/
# 156 Subplot 多合一显示 https://morvanzhou.github.io/tutorials/data-manipulation/plt/4-1-subpot1/
# 157 从头开始做一个机器手臂5 完善测试 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/RL-build-arm-from-scratch5/
# 158 什么是循环神经网络 RNN (Recurrent Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/keras/2-4-A-RNN/
# 159 什么是 强化学习 (Reinforcement Learning) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/1-1-A-RL/
# 160 if else 判断 https://morvanzhou.github.io/tutorials/python-basic/basic/04-2-if-else/
# 161 Actor Critic https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-08-AC/
# 162 什么是 LSTM 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-07-B-LSTM/
# 163 Why Theano? https://morvanzhou.github.io/tutorials/machine-learning/theano/1-1-why/
# 164 Sarsa 思维决策 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/3-2-tabular-sarsa2/
# 165 什么是多线程 Threading https://morvanzhou.github.io/tutorials/python-basic/threading/1-why/
# 166 特征标准化 (Feature Normalization) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-02-normalization/
# 167 从头开始做一个机器手臂1 搭建结构 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/RL-build-arm-from-scratch1/
# 168 用 Tensorflow 可视化梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-15-tf-gradient-descent/
# 169 函数参数 https://morvanzhou.github.io/tutorials/python-basic/basic/05-2-def-parameters/
# 170 Numpy 属性 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-1-np-attributes/
# 171 什么是 Asynchronous Advantage Actor-Critic (A3C) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-3-A1-A3C/
# 172 CNN 卷积神经网络 3 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-05-CNN3/
# 173 进程池 Pool https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/5-pool/
# 174 Matplotlib 安装 https://morvanzhou.github.io/tutorials/data-manipulation/plt/1-2-install/
# 175 LSTM RNN 循环神经网络 (LSTM) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-4-LSTM/
# 176 Placeholder 传入值 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-5-placeholde/
# 177 分支 (branch) https://morvanzhou.github.io/tutorials/others/git/4-1-branch/
# 178 什么是生成对抗网络 (GAN) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-06-A-GAN/
# 179 神经网络 梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-8-gradient-descent/
# 180 变量 (Variable) https://morvanzhou.github.io/tutorials/machine-learning/torch/2-02-variable/
# 181 GAN (Generative Adversarial Nets 生成对抗网络) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-06-GAN/
# 182 Contours 等高线图 https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-3-contours/
# 183 try 错误处理 https://morvanzhou.github.io/tutorials/python-basic/basic/13-02-try/
# 184 例子 旅行商人问题 (Travel Sales Problem) https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/2-03-genetic-algorithm-travel-sales-problem/
# 185 科普: 神经网络的黑盒不黑 https://morvanzhou.github.io/tutorials/machine-learning/theano/1-1-D-feature-representation/
# 186 什么是 Sarsa(lambda) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/3-3-A-sarsa-lambda/
# 187 第一个版本库 Repository https://morvanzhou.github.io/tutorials/others/git/2-1-repository/
# 188 设置坐标轴1 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-3-axis1/
# 189 科普: 人工神经网络 VS 生物神经网络 https://morvanzhou.github.io/tutorials/machine-learning/keras/1-1-A-ANN-and-NN/
# 190 Policy Gradients 思维决策 (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/5-2-policy-gradient-softmax2/
# 191 Git 安装 https://morvanzhou.github.io/tutorials/others/git/1-2-install/
# 192 dictionary 字典 https://morvanzhou.github.io/tutorials/python-basic/basic/11-4-dictionary/
# 193 multiprocessing 什么是多进程 https://morvanzhou.github.io/tutorials/python-basic/basic/13-06-multiprocessing/
# 194 Radiobutton 选择按钮 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-04-radiobutton/
# 195 for 循环 https://morvanzhou.github.io/tutorials/python-basic/basic/03-2-for/
# 196 神经网络 梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/theano/1-1-C-gradient-descent/
# 197 科普: 人工神经网络 VS 生物神经网络 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-1-A-ANN-and-NN/
# 198 机器学习 (Machine Learning) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/1-1-machine-learning/
# 199 例子3 添加层 def add_layer() https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/3-1-add-layer/
# 200 什么是 Sarsa https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/3-1-A-sarsa/
# 201 加速神经网络训练 (Speed Up Training) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-06-speed-up-learning/
# 202 Distributed Proximal Policy Optimization (DPPO) (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-4-DPPO/
# 203 什么是循环神经网络 RNN (Recurrent Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-02-A-RNN/
# 204 机器学习 (Machine Learning) https://morvanzhou.github.io/tutorials/machine-learning/sklearn/1-1-A-ML/
# 205 Numpy 基础运算2 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-4-np-math2/
# 206 BeautifulSoup 解析网页: 基础 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/2-01-beautifulsoup-basic/
# 207 激励函数 (Activation Function) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-04-activation-function/
# 208 L1 / L2 正规化 (Regularization) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-09-l1l2regularization/
# 209 RNN Classifier 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-4-RNN-classifier/
# 210 安装 Ubuntu 17.10 https://morvanzhou.github.io/tutorials/others/linux-basic/1-2-install/
# 211 什么是 Deep Deterministic Policy Gradient (DDPG) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-2-A-DDPG/
# 212 Numpy 的创建 array https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-2-np-array/
# 213 RNN LSTM (回归例子可视化) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-10-RNN4/
# 214 什么是卷积神经网络 CNN (Convolutional Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-03-A-CNN/
# 215 Why Numpy & Pandas? https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/1-1-why/
# 216 可视化结果 回归例子 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-3-visualize/
# 217 通用学习模式 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/2-2-general-pattern/
# 218 figure 图像 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-2-figure/
# 219 例子3 结果可视化 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/3-3-visualize-result/
# 220 copy & deepcopy 浅复制 & 深复制 https://morvanzhou.github.io/tutorials/python-basic/basic/13-04-copy/
# 221 threading 什么是多线程 https://morvanzhou.github.io/tutorials/python-basic/basic/13-05-threading/
# 222 Frame 框架 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-09-frame/
# 223 Tensorflow 安装 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-2-install/
# 224 科普: 神经网络的黑盒不黑 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-1-D-feature-representation/
# 225 自编码 Autoencoder (非监督学习) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-11-autoencoder/
# 226 Numpy 基础运算1 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-3-np-math1/
# 227 Pandas 选择数据 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-2-pd-indexing/
# 228 Sarsa-lambda https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/3-3-tabular-sarsa-lambda/
# 229 读写文件 3 https://morvanzhou.github.io/tutorials/python-basic/basic/08-3-read-file3/
# 230 过拟合 (Overfitting) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-05-overfitting/
# 231 Dueling DQN (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-7-dueling-DQN/
# 232 线程锁 Lock https://morvanzhou.github.io/tutorials/python-basic/threading/6-lock/
# 233 函数默认参数 https://morvanzhou.github.io/tutorials/python-basic/basic/05-3-def-default-parameters/
# 234 小练习: 下载美图 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/3-03-practice-download-image/
# 235 DQN 神经网络 (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-2-DQN2/
# 236 从头开始做一个机器手臂3 写动态环境 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/RL-build-arm-from-scratch3/
# 237 while 循环 https://morvanzhou.github.io/tutorials/python-basic/basic/03-1-while/
# 238 基础数学运算 https://morvanzhou.github.io/tutorials/python-basic/basic/02-2-basic-math/
# 239 图中图 https://morvanzhou.github.io/tutorials/data-manipulation/plt/4-3-plot-in-plot/
# 240 Pandas 基本介绍 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-1-pd-intro/
# 241 加速神经网络训练 (Speed Up Training) https://morvanzhou.github.io/tutorials/machine-learning/torch/3-06-A-speed-up-learning/
# 242 Saver 保存读取 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-06-save/
# 243 什么是 LSTM 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/torch/4-02-B-LSTM/
# 244 回到从前 (checkout 针对单个文件) https://morvanzhou.github.io/tutorials/others/git/3-2-checkout/
# 245 tick 能见度 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-7-tick-visibility/
# 246 从头开始做一个机器手臂4 加入强化学习算法 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/RL-build-arm-from-scratch4/
# 247 Sarsa https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-04-sarsa/
# 248 Asynchronous Advantage Actor-Critic (A3C) (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-3-A3C/
# 249 遗传算法 (Genetic Algorithm) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/5-01-genetic-algorithm/
# 250 CNN 卷积神经网络 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-3-CNN/
# 251 Classifier 分类 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-2-classifier/
# 252 Pytorch 安装 https://morvanzhou.github.io/tutorials/machine-learning/torch/1-2-install/
# 253 Actor Critic (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-1-actor-critic/
# 254 Deep Deterministic Policy Gradient (DDPG) (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/6-2-DDPG/
# 255 Tensorboard 可视化好帮手 2 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/4-2-tensorboard2/
# 256 Why Linux? https://morvanzhou.github.io/tutorials/others/linux-basic/1-1-why/
# 257 OpenAI gym 环境库 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-4-gym/
# 258 Linux 基本指令 nano 和 cat https://morvanzhou.github.io/tutorials/others/linux-basic/2-04-basic-command/
# 259 例子 登录窗口3 https://morvanzhou.github.io/tutorials/python-basic/tkinter/3-03-example3/
# 260 DQN 算法更新 (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-1-DQN1/
# 261 Pandas 合并 merge https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-7-pd-merge/
# 262 Numpy 和 Pandas 安装 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/1-2-install/
# 263 小练习: 爬百度百科 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/2-04-practice-baidu-baike/
# 264 自己的云计算, 把 Linux 当成你的云计算平台 https://morvanzhou.github.io/tutorials/others/linux-basic/5-01-remote-learning/
# 265 Function 用法 https://morvanzhou.github.io/tutorials/machine-learning/theano/2-2-function/
# 266 Autoencoder 自编码 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-6-autoencoder/
# 267 Q-learning 思维决策 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/2-3-tabular-q2/
# 268 (1+1)-ES https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/3-02-evolution-strategy-1+1-ES/
# 269 例子 配对句子 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/2-02-genetic-algorithm-match-phrase/
# 270 为什么用 Numpy 还是慢, 你用对了吗? https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/4-1-speed-up-numpy/
# 271 AlphaGo Zero 为什么更厉害? https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-11-AlphaGo-zero/
# 272 进程锁 Lock https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/7-lock/
# 273 什么是自编码 (Autoencoder) https://morvanzhou.github.io/tutorials/machine-learning/keras/2-6-A-autoencoder/
# 274 class 类 init 功能 https://morvanzhou.github.io/tutorials/python-basic/basic/09-2-class-init/
# 275 基本用法 https://morvanzhou.github.io/tutorials/machine-learning/theano/2-1-basic-usage/
# 276 什么是过拟合 (Overfitting) https://morvanzhou.github.io/tutorials/machine-learning/theano/3-5-A-overfitting/
# 277 Pandas 合并 concat https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-6-pd-concat/
# 278 卷积神经网络 CNN (Convolutional Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-2-CNN/
# 279 join 功能 https://morvanzhou.github.io/tutorials/python-basic/threading/3-join/
# 280 强化学习方法汇总 (Reinforcement Learning) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/1-1-B-RL-methods/
# 281 课程要求 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/1-2-requirment/
# 282 生成对抗网络 (GAN) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-6-GAN/
# 283 Prioritized Experience Replay (DQN) (Tensorflow) https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/4-6-prioritized-replay/
# 284 CNN 卷积神经网络 https://morvanzhou.github.io/tutorials/machine-learning/torch/4-01-CNN/
# 285 Listbox 列表部件 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-03-listbox/
# 286 小例子 https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/2-1-general-rl/
# 287 神经网络 梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/keras/1-1-C-gradient-descent/
# 288 Numpy 索引 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/2-5-np-indexing/
# 289 sklearn 强大数据库 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/2-3-database/
# 290 Session 会话控制 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-3-session/
# 291 Classification 分类学习 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-4-classification/
# 292 什么是进化策略 (Evolution Strategy) https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/3-00-evolution-strategy/
# 293 Annotation 标注 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-6-annotation/
# 294 多功能的 Requests https://morvanzhou.github.io/tutorials/data-manipulation/scraping/3-01-requests/
# 295 Variable 变量 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-4-variable/
# 296 RNN 循环神经网络 (回归) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-03-RNN-regression/
# 297 什么是卷积神经网络 CNN (Convolutional Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-01-A-CNN/
# 298 什么是循环神经网络 RNN (Recurrent Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-07-A-RNN/
# 299 merge 分支冲突 https://morvanzhou.github.io/tutorials/others/git/4-2-merge-conflict/
# 300 什么是自编码 (Autoencoder) https://morvanzhou.github.io/tutorials/machine-learning/torch/4-04-A-autoencoder/
# 301 什么是神经网络 (Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/torch/1-1-B-NN/
# 302 添加进程 Process https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/2-add/
# 303 下载文件 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/3-02-download/
# 304 GIL 不一定有效率 https://morvanzhou.github.io/tutorials/python-basic/threading/5-GIL/
# 305 区分类型 (分类) https://morvanzhou.github.io/tutorials/machine-learning/torch/3-02-classification/
# 306 加速爬虫: 异步加载 Asyncio https://morvanzhou.github.io/tutorials/data-manipulation/scraping/4-02-asyncio/
# 307 保存模型 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-5-save/
# 308 Save & reload 保存提取 https://morvanzhou.github.io/tutorials/machine-learning/keras/3-1-save/
# 309 3D 数据 https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-5-3d/
# 310 选择学习方法 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/2-1-select-method/
# 311 共享内存 shared memory https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/6-shared-memory/
# 312 多维列表 https://morvanzhou.github.io/tutorials/python-basic/basic/11-3-multi-dim-list/
# 313 神经网络 梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-1-C-gradient-descent/
# 314 Linux 基本指令 touch, cp 和 mv https://morvanzhou.github.io/tutorials/others/linux-basic/2-02-basic-command/
# 315 什么是 Multiprocessing https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/1-why/
# 316 Sarsa(lambda) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-05-sarsa-lambda/
# 317 Why Git? https://morvanzhou.github.io/tutorials/others/git/1-1-why/
# 318 强化学习 (Reinforcement Learning) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-01-RL/
# 319 加速神经网络训练 (Speed Up Training) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/3-4-A-speed-up-learning/
# 320 class 类 https://morvanzhou.github.io/tutorials/python-basic/basic/09-1-class/
# 321 什么是 LSTM 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-4-B-LSTM/
# 322 Pandas 导入导出 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-5-pd-to/
# 323 设置坐标轴2 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-4-axis2/
# 324 进化策略 https://morvanzhou.github.io/tutorials/machine-learning/evolutionary-algorithm/3-01-evolution-strategy/
# 325 Q Leaning https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-03-q-learning/
# 326 Batch Normalization 批标准化 https://morvanzhou.github.io/tutorials/machine-learning/torch/5-04-batch-normalization/
# 327 Why Keras? https://morvanzhou.github.io/tutorials/machine-learning/keras/1-1-why/
# 328 Animation 动画 https://morvanzhou.github.io/tutorials/data-manipulation/plt/5-1-animation/
# 329 CNN 卷积神经网络 2 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-04-CNN2/
# 330 怎么样从 Windows 通过 SSH 远程 Linux https://morvanzhou.github.io/tutorials/others/linux-basic/4-02-ssh-from-windows/
# 331 总结和更多 https://morvanzhou.github.io/tutorials/machine-learning/theano/4-1-summary/
# 332 zip lambda map https://morvanzhou.github.io/tutorials/python-basic/basic/13-03-zip-lambda-map/
# 333 怎么样用 TeamViewer 和 VNC 从远程控制电脑 https://morvanzhou.github.io/tutorials/others/linux-basic/4-04-teamviewer-vnc/
# 334 储存进程结果 Queue https://morvanzhou.github.io/tutorials/python-basic/threading/4-queue/
# 335 科普: 人工神经网络 VS 生物神经网络 https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-0-ANN-and-NN/
# 336 Sklearn 安装 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/1-2-install/
# 337 RNN Regressor 循环神经网络 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-5-RNN-LSTM-Regressor/
# 338 什么是激励函数 (Activation Function) https://morvanzhou.github.io/tutorials/machine-learning/torch/2-03-A-activation-function/
# 339 if 判断 https://morvanzhou.github.io/tutorials/python-basic/basic/04-1-if/
# 340 存储进程输出 Queue https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/3-queue/
# 341 全局 & 局部 变量 https://morvanzhou.github.io/tutorials/python-basic/basic/06-1-global-local/
# 342 什么是神经网络 (Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/keras/1-1-B-NN/
# 343 什么是批标准化 (Batch Normalization) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-13-A-batch-normalization/
# 344 循环神经网络 RNN (Recurrent Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/2-3-RNN/
# 345 处理结构 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-1-structure/
# 346 Regression 回归例子 https://morvanzhou.github.io/tutorials/machine-learning/theano/3-2-regression/
# 347 加速爬虫: 多进程分布式 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/4-01-distributed-scraping/
# 348 Asynchronous Advantage Actor-Critic (A3C) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/4-10-A3C/
# 349 什么是卷积神经网络 CNN (Convolutional Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/keras/2-3-A-CNN/
# 350 Torch 或 Numpy https://morvanzhou.github.io/tutorials/machine-learning/torch/2-01-torch-numpy/
# 351 神经网络在干嘛 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-3-what-does-NN-do/
# 352 效率对比 threading & multiprocessing https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/4-comparison/
# 353 从头开始做一个汽车状态分类器2: 搭建模型 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/build-car-classifier-from-scratch2/
# 354 添加线程 Thread https://morvanzhou.github.io/tutorials/python-basic/threading/2-add-thread/
# 355 例子2 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-2-example2/
# 356 基本用法 https://morvanzhou.github.io/tutorials/data-manipulation/plt/2-1-basic-usage/
# 357 了解网页结构 https://morvanzhou.github.io/tutorials/data-manipulation/scraping/1-01-understand-website/
# 358 import 模块 https://morvanzhou.github.io/tutorials/python-basic/basic/12-1-import/
# 359 sklearn 常用属性与功能 https://morvanzhou.github.io/tutorials/machine-learning/sklearn/2-4-model-attributes/
# 360 什么是 DQN https://morvanzhou.github.io/tutorials/machine-learning/torch/4-05-A-DQN/
# 361 神经网络在做什么 https://morvanzhou.github.io/tutorials/machine-learning/theano/1-3-NN-job/
# 362 正则表达式 https://morvanzhou.github.io/tutorials/python-basic/basic/13-10-regular-expression/
# 363 Pandas 设置值 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-3-pd-assign/
# 364 Theano 安装 https://morvanzhou.github.io/tutorials/machine-learning/theano/1-2-install/
# 365 Canvas 画布 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-07-canvas/
# 366 从头开始做一个汽车状态分类器1: 分析数据 https://morvanzhou.github.io/tutorials/machine-learning/ML-practice/build-car-classifier-from-scratch1/
# 367 Classification 分类学习 https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-01-classifier/
# 368 Image 图片 https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-4-image/
# 369 选择好特征 (Good Features) https://morvanzhou.github.io/tutorials/machine-learning/ML-intro/3-03-choose-feature/
# 370 什么是批标准化 (Batch Normalization) https://morvanzhou.github.io/tutorials/machine-learning/torch/5-04-A-batch-normalization/
# 371 Label & Button 标签和按钮 https://morvanzhou.github.io/tutorials/python-basic/tkinter/2-01-label-button/
# 372 Linux 基本指令 ls 和 cd https://morvanzhou.github.io/tutorials/others/linux-basic/2-01-basic-command/
# 373 变量 variable https://morvanzhou.github.io/tutorials/python-basic/basic/02-3-variable/
# 374 检验神经网络 (Evaluation) https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-2-A-Evaluate-NN/
# 375 Pandas plot 出图 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-8-pd-plot/
# 376 什么是神经网络 (Neural Network) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/1-1-B-NN/
# 377 神经网络 梯度下降 https://morvanzhou.github.io/tutorials/machine-learning/torch/1-1-C-gradient-descent/
# 378 交叉验证 2 Cross-validation https://morvanzhou.github.io/tutorials/machine-learning/sklearn/3-3-cross-validation2/
# 379 快速了解 Ubuntu 17.10 基本界面 https://morvanzhou.github.io/tutorials/others/linux-basic/1-3-system-overview/
# 380 BeautifulSoup 解析网页: CSS https://morvanzhou.github.io/tutorials/data-manipulation/scraping/2-02-beautifulsoup-css/
# 381 Pandas 处理丢失数据 https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-4-pd-nan/
# 382 批训练 https://morvanzhou.github.io/tutorials/machine-learning/torch/3-05-train-on-batch/
# 383 Dropout 缓解过拟合 https://morvanzhou.github.io/tutorials/machine-learning/torch/5-03-dropout/
# 384 GPU 加速运算 https://morvanzhou.github.io/tutorials/machine-learning/torch/5-02-GPU/
# 385 什么是激励函数 (Activation Function) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/2-6-A-activation-function/
# 386 Regressor 回归 https://morvanzhou.github.io/tutorials/machine-learning/keras/2-1-regressor/
# 387 RNN LSTM (回归例子) https://morvanzhou.github.io/tutorials/machine-learning/tensorflow/5-09-RNN3/
# 388 次坐标轴 https://morvanzhou.github.io/tutorials/data-manipulation/plt/4-4-sencondary-axis/
# Total time: 373.1 s

# %% [markdown]
# ### multiprocessing
# Create a process pool and scrape parallelly.

# %%
unseen = set([base_url,])
seen = set()

pool = mp.Pool(4)                       
count, t1 = 1, time.time()
while len(unseen) != 0:                 # still get some url to visit
    if restricted_crawl and len(seen) > 10:
            break
    print('\nDistributed Crawling...')
    crawl_jobs = [pool.apply_async(crawl, args=(url,)) for url in unseen]
    htmls = [j.get() for j in crawl_jobs]                                       # request connection

    print('\nDistributed Parsing...')
    parse_jobs = [pool.apply_async(parse, args=(html,)) for html in htmls]
    results = [j.get() for j in parse_jobs]                                     # parse html

    print('\nAnalysing...')
    seen.update(unseen)         # seen the crawled
    unseen.clear()              # nothing unseen

    for title, page_urls, url in results:
        print(count, title, url)
        count += 1
        unseen.update(page_urls - seen)     # get new url to crawl
print('Total time: %.1f s' % (time.time()-t1, ))    # 16 s !!!
# Out:
# Distributed Crawling...
